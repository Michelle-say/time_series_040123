# %%
import pandas as pd
import pmdarima as pm
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
df = pd.read_csv('../csv/sncf_clean.csv')

# %%
df.drop(['restitution_date','nom', 'gare', 'type', 'nature'], axis=1, inplace=True)

# %%
df1 = df.groupby(['date', 'year', 'month', 'week', 'day', 'day_of_week']).sum().reset_index()

# %%
df1 = df1.loc[df1['year']<=2022]

# %%
df1_month = df1[['year', 'month', 'number']].groupby(['year', 'month']).sum().reset_index()
df1_week = df1[['year', 'week', 'number']].groupby(['year', 'week']).sum().reset_index()

# %%
model_arima_day = pm.auto_arima(df1['number'], start_p=1, start_q=1,
                      test='adf',
                      max_p=3, max_q=3, 
                      m=1,              
                      d=None,           
                      seasonal=True,   
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=14329.974, Time=2.30 sec
#  ARIMA(0,0,0)(0,0,0)[0] intercept   : AIC=15155.120, Time=0.08 sec
#  ARIMA(1,0,0)(0,0,0)[0] intercept   : AIC=14927.188, Time=0.51 sec
#  ARIMA(0,0,1)(0,0,0)[0] intercept   : AIC=14993.396, Time=0.52 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=18468.730, Time=0.05 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=14330.405, Time=2.84 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=14330.136, Time=2.98 sec
#  ARIMA(0,0,2)(0,0,0)[0] intercept   : AIC=14926.918, Time=0.78 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=14815.037, Time=0.25 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=14329.890, Time=3.48 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=14324.978, Time=4.10 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=14326.753, Time=3.64 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=14316.393, Time=5.38 sec
# ...

# %%
model_arima_day.plot_diagnostics(figsize=(7,5))
plt.show()

# %%
model_arima_month = pm.auto_arima(df1_month['number'], start_p=1, start_q=1,
                      test='adf',
                      max_p=3, max_q=3, 
                      m=1,              
                      d=None,           
                      seasonal=True,   
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=869.146, Time=0.12 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=875.320, Time=0.02 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=872.733, Time=0.06 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=869.761, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=873.355, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=870.988, Time=0.17 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=870.969, Time=0.18 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=869.077, Time=0.14 sec
#  ARIMA(0,1,3)(0,0,0)[0] intercept   : AIC=870.971, Time=0.22 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=872.883, Time=0.22 sec
#  ARIMA(0,1,2)(0,0,0)[0]             : AIC=867.244, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0]             : AIC=867.847, Time=0.05 sec
#  ARIMA(1,1,2)(0,0,0)[0]             : AIC=869.159, Time=0.13 sec
#  ARIMA(0,1,3)(0,0,0)[0]             : AIC=869.158, Time=0.12 sec
# ...

# %%
model_arima_month.plot_diagnostics(figsize=(7,5))
plt.show()

# %%
model_arima_week = pm.auto_arima(df1_week['number'], start_p=1, start_q=1,
                      test='adf',
                      max_p=3, max_q=3, 
                      m=1,              
                      d=None,           
                      seasonal=True,   
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=2911.252, Time=0.28 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=3025.275, Time=0.03 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=2948.393, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=2915.460, Time=0.11 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=3023.275, Time=0.02 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=2905.911, Time=0.34 sec
#  ARIMA(2,1,0)(0,0,0)[0] intercept   : AIC=2934.679, Time=0.13 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=2907.613, Time=0.40 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=2907.690, Time=0.47 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=2907.130, Time=0.46 sec
#  ARIMA(3,1,0)(0,0,0)[0] intercept   : AIC=2930.706, Time=0.21 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=2909.736, Time=0.39 sec
#  ARIMA(2,1,1)(0,0,0)[0]             : AIC=2904.091, Time=0.14 sec
#  ARIMA(1,1,1)(0,0,0)[0]             : AIC=2909.351, Time=0.10 sec
# ...

# %%
model_arima_week.plot_diagnostics(figsize=(7,5))
plt.show()

# %%
model_statsmodel_day = SARIMAX(df1["number"], order=(3, 0, 3), seasonal_order=(0, 0, 0, 365), trend='ct', enforce_invertibility=False)

# %%
results = model_statsmodel_day.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                 number   No. Observations:                 2447
# Model:               SARIMAX(3, 0, 3)   Log Likelihood               -7227.001
# Date:                Thu, 05 Jan 2023   AIC                          14472.001
# Time:                        15:49:01   BIC                          14524.225
# Sample:                             0   HQIC                         14490.981
#                                - 2447
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      4.4386      1.036      4.285      0.000       2.408       6.469
# drift         -0.0012      0.000     -4.190      0.000      -0.002      -0.001
# ar.L1          0.2376      0.237      1.000      0.317      -0.228       0.703
# ...

# %%
model_statsmodel_week = SARIMAX(df1_week["number"], order=(2, 1, 1), seasonal_order=(0, 0, 0, 53), trend='ct', enforce_invertibility=False)

# %%
results = model_statsmodel_week.fit()
results.summary()
# Out:
# e:\logiciel\Nouveau dossier\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                 number   No. Observations:                  360
# Model:               SARIMAX(2, 1, 1)   Log Likelihood               -1448.012
# Date:                Thu, 05 Jan 2023   AIC                           2908.023
# Time:                        15:49:01   BIC                           2931.323
# Sample:                             0   HQIC                          2917.289
#                                 - 360
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ...

# %%
model_statsmodel_month = SARIMAX(df1_month["number"], order=(0, 1, 2), seasonal_order=(0, 0, 0, 12), trend='ct', enforce_invertibility=False)

# %%
results = model_statsmodel_month.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                 number   No. Observations:                   83
# Model:               SARIMAX(0, 1, 2)   Log Likelihood                -430.530
# Date:                Thu, 05 Jan 2023   AIC                            871.060
# Time:                        15:49:02   BIC                            883.093
# Sample:                             0   HQIC                           875.891
#                                  - 83
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept     -1.6495      6.473     -0.255      0.799     -14.337      11.038
# drift          0.0147      0.152      0.097      0.923      -0.283       0.312
# ma.L1         -0.3308      0.121     -2.724      0.006      -0.569      -0.093
# ...
